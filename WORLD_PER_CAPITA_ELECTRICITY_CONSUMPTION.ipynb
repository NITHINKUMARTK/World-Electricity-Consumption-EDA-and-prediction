# %% [markdown]
# # **WORLD ELECTRICITY CONSUMPTION EDA AND PREDICTION**

# %% [markdown]
# ***Datset Link:*** https://drive.google.com/file/d/1NYKm9PnVt0jGQRciwY6dnyI8opR-X81D/view?usp=sharing

# %% [markdown]
# ***EXPLORATORY DATA ANALYSIS***

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("World_Per_Capita_Electricity_Consumption.csv")
data.head()
# Out:
#         Entity  Year  Per capita electricity (kWh)
# 0  Afghanistan  2000                        22.474
# 1  Afghanistan  2001                        27.399
# 2  Afghanistan  2002                        30.397
# 3  Afghanistan  2003                        39.652
# 4  Afghanistan  2004                        36.155

# %%
data.tail()
# Out:
#         Entity  Year  Per capita electricity (kWh)
# 5615  Zimbabwe  2015                       679.553
# 5616  Zimbabwe  2016                       486.509
# 5617  Zimbabwe  2017                       513.434
# 5618  Zimbabwe  2018                       632.533
# 5619  Zimbabwe  2019                       617.672

# %%
data.shape
# Out:
# (5620, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5620 entries, 0 to 5619
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Entity                        5620 non-null   object
#  1   Year                          5620 non-null   int64
#  2   Per capita electricity (kWh)  5620 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 131.8+ KB

# %%
data.columns
# Out:
# Index(['Entity', 'Year', 'Per capita electricity (kWh)'], dtype='object')

# %%
data["Entity"].nunique()
# Out:
# 213

# %%
data["Entity"].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia', 'Democratic Republic of Congo',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Europe', 'European Union (27)', 'Falkland Islands',
# ...

# %%
data["Entity"].value_counts()
# Out:
# Latvia                  37
# Bulgaria                37
# Cyprus                  37
# Czechia                 37
# Denmark                 37
#                         ..
# Haiti                   20
# Honduras                20
# Jamaica                 20
# Jordan                  20
# Netherlands Antilles    18
# Name: Entity, Length: 213, dtype: int64

# %%
data.isnull().sum()
# Out:
# Entity                          0
# Year                            0
# Per capita electricity (kWh)    0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  Per capita electricity (kWh)
# count  5620.000000                   5620.000000
# mean   2005.826157                   4095.887211
# std       9.238193                   5403.908499
# min    1985.000000                      0.000000
# 25%    2000.000000                    646.116250
# 50%    2007.000000                   2555.821500
# 75%    2013.000000                   5561.172750
# max    2021.000000                  58863.361000

# %%
data["Per capita electricity (kWh)"].max()
# Out:
# 58863.361

# %%
data.groupby(["Entity"])["Per capita electricity (kWh)"].max()
# Out:
# Entity
# Afghanistan         39.652
# Africa             665.896
# Albania           2965.933
# Algeria           1727.395
# American Samoa    2946.919
#                     ...
# Western Sahara     253.539
# World             3361.385
# Yemen              317.927
# Zambia             943.653
# Zimbabwe           782.951
# Name: Per capita electricity (kWh), Length: 213, dtype: float64

# %%
data.groupby(["Entity","Year"])["Per capita electricity (kWh)"].max()
# Out:
# Entity       Year
# Afghanistan  2000     22.474
#              2001     27.399
#              2002     30.397
#              2003     39.652
#              2004     36.155
#                       ...
# Zimbabwe     2015    679.553
#              2016    486.509
#              2017    513.434
#              2018    632.533
#              2019    617.672
# Name: Per capita electricity (kWh), Length: 5620, dtype: float64

# %%
data.groupby(["Year"])["Per capita electricity (kWh)"].max()
# Out:
# Year
# 1985    24870.994
# 1986    23333.313
# 1987    24906.543
# 1988    26158.125
# 1989    28204.858
# 1990    28597.085
# 1991    25872.094
# 1992    27257.998
# 1993    27708.089
# 1994    25842.912
# 1995    27966.593
# 1996    23802.603
# 1997    24971.348
# 1998    26151.859
# 1999    27302.142
# 2000    31655.508
# 2001    28383.585
# 2002    33023.736
# 2003    32636.248
# 2004    32305.433
# 2005    33935.413
# 2006    38175.762
# 2007    41194.893
# 2008    52982.902
# 2009    53249.888
# 2010    53255.583
# 2011    53204.151
# 2012    53893.540
# 2013    55349.426
# 2014    55144.374
# 2015    56898.530
# 2016    55838.343
# 2017    57536.745
# 2018    58863.361
# 2019    57486.351
# 2020    27798.058
# 2021    27213.702
# Name: Per capita electricity (kWh), dtype: float64

# %% [markdown]
# **EDA OF ELECTRICITY CONSUMPTION OF INDIA, USA AND CHINA**

# %% [markdown]
# ***ANALYSING INDIAN ELECTRICITY CONSUMPTION***

# %%
india_consumption = data[data["Entity"] == "India"]
india_consumption
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 2307  India  1985                       237.628
# 2308  India  1986                       252.723
# 2309  India  1987                       272.873
# 2310  India  1988                       288.136
# 2311  India  1989                       318.526
# 2312  India  1990                       329.520
# 2313  India  1991                       359.550
# 2314  India  1992                       370.781
# 2315  India  1993                       390.527
# 2316  India  1994                       410.286
# 2317  India  1995                       443.136
# 2318  India  1996                       451.162
# 2319  India  1997                       468.732
# 2320  India  1998                       495.426
# 2321  India  1999                       527.295
# 2322  India  2000                       460.100
# 2323  India  2001                       472.838
# 2324  India  2002                       475.286
# 2325  India  2003                       495.287
# ...

# %%
india_consumption.sort_values(by ="Per capita electricity (kWh)",ascending = False)
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 2340  India  2018                      1011.229
# 2341  India  2019                      1008.604
# 2342  India  2020                       972.437
# 2339  India  2017                       960.455
# 2338  India  2016                       924.206
# 2337  India  2015                       869.785
# 2336  India  2014                       851.348
# 2335  India  2013                       784.507
# 2334  India  2012                       754.648
# 2333  India  2011                       722.896
# 2332  India  2010                       667.616
# 2331  India  2009                       641.219
# 2330  India  2008                       604.211
# 2329  India  2007                       586.312
# 2328  India  2006                       566.615
# 2327  India  2005                       536.013
# 2321  India  1999                       527.295
# 2326  India  2004                       519.412
# 2320  India  1998                       495.426
# ...

# %% [markdown]
# ***OBSERVATION***
#
# In 2018 the per capita electricity consumption of India is more which is 1011.229 kWh and minimum in the year 1985 which is 237.628 kWh

# %%
india_consumption.describe()
# Out:
#               Year  Per capita electricity (kWh)
# count    36.000000                     36.000000
# mean   2002.500000                    569.481250
# std      10.535654                    229.580859
# min    1985.000000                    237.628000
# 25%    1993.750000                    405.346250
# 50%    2002.500000                    507.419000
# 75%    2011.250000                    730.834000
# max    2020.000000                   1011.229000

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = "Year", y = "Per capita electricity (kWh)",hue = "Entity", data =india_consumption,palette = "hot")
plt.xticks(rotation = 90)
plt.title("Per Capita Electricity Consumption of India")
# Out:
# Text(0.5, 1.0, 'Per Capita Electricity Consumption of India')

# %%
plt.figure(figsize = (10,12))
sns.lmplot(x = "Year", y = "Per capita electricity (kWh)", data = india_consumption)
plt.show()

# %%
plt.plot(data['Year'][data['Entity']=='India'],
data['Per capita electricity (kWh)'][data['Entity']=="India"])
plt.title("India Electricity Consumption")
plt.show()

# %% [markdown]
# ***ANALYSING UNITED STATES ELECTRICITY CONSUMPTION***

# %%
usa_consumption = data[data["Entity"] == "United States"]
usa_consumption
# Out:
#              Entity  Year  Per capita electricity (kWh)
# 5301  United States  1985                     11048.449
# 5302  United States  1986                     11023.556
# 5303  United States  1987                     11312.686
# 5304  United States  1988                     11781.619
# 5305  United States  1989                     12635.657
# 5306  United States  1990                     12822.369
# 5307  United States  1991                     12849.582
# 5308  United States  1992                     12780.194
# 5309  United States  1993                     13118.522
# 5310  United States  1994                     13188.340
# 5311  United States  1995                     13453.314
# 5312  United States  1996                     13652.286
# 5313  United States  1997                     13677.552
# 5314  United States  1998                     14012.189
# 5315  United States  1999                     14130.762
# 5316  United States  2000                     13496.477
# ...

# %%
usa_consumption.sort_values(by ="Per capita electricity (kWh)",ascending = False)
# Out:
#              Entity  Year  Per capita electricity (kWh)
# 5315  United States  1999                     14130.762
# 5314  United States  1998                     14012.189
# 5323  United States  2007                     13827.772
# 5321  United States  2005                     13747.498
# 5313  United States  1997                     13677.552
# 5312  United States  1996                     13652.286
# 5322  United States  2006                     13650.981
# 5320  United States  2004                     13581.296
# 5324  United States  2008                     13573.567
# 5316  United States  2000                     13496.477
# 5311  United States  1995                     13453.314
# 5318  United States  2002                     13431.013
# 5319  United States  2003                     13398.815
# 5326  United States  2010                     13349.213
# 5310  United States  1994                     13188.340
# 5327  United States  2011                     13159.021
# ...

# %% [markdown]
# ***OBSERVATION:***
#
# The USA consumption of electricity is more in the year 1999 which is 14130.762 kWh and minimum in the year 1986 which is 11023.556 kWh

# %%
usa_consumption.describe()
# Out:
#               Year  Per capita electricity (kWh)
# count    36.000000                     36.000000
# mean   2002.500000                  12972.178861
# std      10.535654                    756.084558
# min    1985.000000                  11023.556000
# 25%    1993.750000                  12733.491000
# 50%    2002.500000                  13007.569000
# 75%    2011.250000                  13515.749500
# max    2020.000000                  14130.762000

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = "Year", y = "Per capita electricity (kWh)", data = usa_consumption,hue = "Entity", palette = "magma")
plt.title("Per capita electricity (kWh) consumption of USA")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10,12))
sns.lmplot(x = "Year", y = "Per capita electricity (kWh)", data = usa_consumption)
plt.show()

# %%
plt.plot(data['Year'][data['Entity']=='United States'],
data['Per capita electricity (kWh)'][data['Entity']=="United States"])
plt.title("United States Electricity Consumption")
plt.show()

# %% [markdown]
# ***ANALYSING CHINA ELECTRICITY CONSUMPTION***

# %%
china_consumption = data[data["Entity"] == "China"]
china_consumption
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 1022  China  1985                       381.828
# 1023  China  1986                       410.524
# 1024  China  1987                       445.542
# 1025  China  1988                       479.211
# 1026  China  1989                       504.861
# 1027  China  1990                       527.835
# 1028  China  1991                       567.987
# 1029  China  1992                       624.789
# 1030  China  1993                       665.883
# 1031  China  1994                       754.297
# 1032  China  1995                       811.519
# 1033  China  1996                       863.917
# 1034  China  1997                       899.805
# 1035  China  1998                       917.466
# 1036  China  1999                       967.059
# 1037  China  2000                      1022.123
# 1038  China  2001                      1126.855
# 1039  China  2002                      1249.959
# 1040  China  2003                      1413.067
# ...

# %%
china_consumption.sort_values(by ="Per capita electricity (kWh)",ascending = False)
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 1057  China  2020                      5296.721
# 1056  China  2019                      5110.046
# 1055  China  2018                      4900.508
# 1054  China  2017                      4538.073
# 1053  China  2016                      4259.257
# 1052  China  2015                      4080.043
# 1051  China  2014                      4004.776
# 1050  China  2013                      3859.648
# 1049  China  2012                      3602.411
# 1048  China  2011                      3428.557
# 1047  China  2010                      3086.964
# 1046  China  2009                      2699.810
# 1045  China  2008                      2535.039
# 1044  China  2007                      2397.538
# 1043  China  2006                      2077.550
# 1042  China  2005                      1819.561
# 1041  China  2004                      1633.289
# 1040  China  2003                      1413.067
# 1039  China  2002                      1249.959
# ...

# %% [markdown]
# ***OBSERVATION:***
#
# The electricity consumption of china is more in the year 2020 which is 5296.721 kWh and less in the year 1985 which is 381.828 kWh.

# %%
china_consumption.describe()
# Out:
#               Year  Per capita electricity (kWh)
# count    36.000000                     36.000000
# mean   2002.500000                   2054.564389
# std      10.535654                   1598.410339
# min    1985.000000                    381.828000
# 25%    1993.750000                    732.193500
# 50%    2002.500000                   1331.513000
# 75%    2011.250000                   3472.020500
# max    2020.000000                   5296.721000

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = "Year", y ="Per capita electricity (kWh)", data = china_consumption, hue = "Entity", palette = "Accent")
plt.title("Per capita electricity (kWh) consumption of china")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10,12))
sns.lmplot(x = "Year", y = "Per capita electricity (kWh)", data = china_consumption)
plt.show()

# %%
plt.plot(data['Year'][data['Entity']=='China'],
data['Per capita electricity (kWh)'][data['Entity']=="China"])
plt.title("China Electricity Consumption")
plt.show()

# %%
plt.figure(figsize = (8,8))

plt.plot(data['Year'][data['Entity']=='India'],
data['Per capita electricity (kWh)'][data['Entity']=="India"],color = "green",label = "India")

plt.plot(data['Year'][data['Entity']=='United States'],
data['Per capita electricity (kWh)'][data['Entity']=="United States"],color = "red",label = "USA")

plt.plot(data['Year'][data['Entity']=='China'],
data['Per capita electricity (kWh)'][data['Entity']=="China"],color = "blue",label = "China")

plt.title("Per capita electricity (kWh) consumption")
plt.legend(loc =0)
plt.show()

# %% [markdown]
# ***OBSERVATION:***
#
#
#
# 1.  USA is the largest consumer of electricity and china is the second largest consumer of electricity and India is in the third place.
# 2. The electric consumption of china is increasing yearly where as the consumption of USA is not stable (increasing or decreasing).
# 3. The electric consumption of India has also increased yearly till 2000 and decreased after 2000 and again shows increasing trend till 2018 and shows decreasing trend afterwards.

# %% [markdown]
# # **TRAINING THE MODEL**

# %% [markdown]
# ***TRAINING THE MODEL FOR PREDICTING INDIA'S CONSUMPTION***

# %%
india_consumption
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 2307  India  1985                       237.628
# 2308  India  1986                       252.723
# 2309  India  1987                       272.873
# 2310  India  1988                       288.136
# 2311  India  1989                       318.526
# 2312  India  1990                       329.520
# 2313  India  1991                       359.550
# 2314  India  1992                       370.781
# 2315  India  1993                       390.527
# 2316  India  1994                       410.286
# 2317  India  1995                       443.136
# 2318  India  1996                       451.162
# 2319  India  1997                       468.732
# 2320  India  1998                       495.426
# 2321  India  1999                       527.295
# 2322  India  2000                       460.100
# 2323  India  2001                       472.838
# 2324  India  2002                       475.286
# 2325  India  2003                       495.287
# ...

# %%
X_india = india_consumption.iloc[:,1].values.reshape(36,1)
y_india = india_consumption.iloc[:,-1].values

# %%
print(X_india.shape)
print(X_india)
# Out:
# (36, 1)
# [[1985]
#  [1986]
#  [1987]
#  [1988]
#  [1989]
#  [1990]
#  [1991]
#  [1992]
#  [1993]
#  [1994]
#  [1995]
#  [1996]
#  [1997]
#  [1998]
#  [1999]
#  [2000]
#  [2001]
#  [2002]
#  [2003]
#  [2004]
#  [2005]
#  [2006]
#  [2007]
#  [2008]
#  [2009]
#  [2010]
#  [2011]
#  [2012]
#  [2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]]

# %%
print(y_india.shape)
print(y_india)
# Out:
# (36,)
# [ 237.628  252.723  272.873  288.136  318.526  329.52   359.55   370.781
#   390.527  410.286  443.136  451.162  468.732  495.426  527.295  460.1
#   472.838  475.286  495.287  519.412  536.013  566.615  586.312  604.211
#   641.219  667.616  722.896  754.648  784.507  851.348  869.785  924.206
#   960.455 1011.229 1008.604  972.437]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_india,y_india,test_size = 1/3, random_state = 0)
print(X_train)
# Out:
# [[2018]
#  [2013]
#  [2017]
#  [1993]
#  [1998]
#  [1990]
#  [2002]
#  [1999]
#  [1992]
#  [2011]
#  [1986]
#  [1997]
#  [2010]
#  [2009]
#  [1991]
#  [2008]
#  [1989]
#  [2003]
#  [2006]
#  [2004]
#  [1994]
#  [2019]
#  [1988]
#  [1985]]

# %%
X_test
# Out:
# array([[2016],
#        [2005],
#        [2001],
#        [2015],
#        [2007],
#        [2000],
#        [1995],
#        [1987],
#        [1996],
#        [2014],
#        [2012],
#        [2020]])

# %%
y_train
# Out:
# array([1011.229,  784.507,  960.455,  390.527,  495.426,  329.52 ,
#         475.286,  527.295,  370.781,  722.896,  252.723,  468.732,
#         667.616,  641.219,  359.55 ,  604.211,  318.526,  495.287,
#         566.615,  519.412,  410.286, 1008.604,  288.136,  237.628])

# %%
y_test
# Out:
# array([924.206, 536.013, 472.838, 869.785, 586.312, 460.1  , 443.136,
#        272.873, 451.162, 851.348, 754.648, 972.437])

# %%
from sklearn.linear_model import LinearRegression
model_india = LinearRegression()
model_india.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Coefficient: ",model_india.coef_)
print("intercept: ",model_india.intercept_)
# Out:
# Coefficient:  [20.71586245]
# intercept:  -40912.94497419852

# %%
y_pred = model_india.predict(X_test)

# %% [markdown]
# ***VISUALIZING TRAINING SET RESULTS***

# %%
plt.scatter(X_train, y_train, color = 'green',label = "Actual value")
plt.plot(X_train, model_india.predict(X_train), color = 'red', label = "Predicted value")
plt.title('INDIA(Training data)',color= "blue")
plt.xlabel('Year',color = "red")
plt.ylabel("per capital electricity consumption(kWh)",color = "red")
plt.legend(loc= 0)
plt.show()

# %% [markdown]
# ***VISUALIZING THE TEST RESULTS***

# %%
plt.scatter(X_test, y_test, color = 'green',label = "Actual value")
plt.plot(X_train, model_india.predict(X_train), color = 'red', label = "Predicted value")
plt.title('INDIA(Testing data)',color= "blue")
plt.xlabel('Year',color = "red")
plt.ylabel("per capital electricity consumption(kWh)",color = "red")
plt.legend(loc = 0)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test,y_pred, squared = True)
print(error)
# Out:
# 2793.214567211781

# %%
years=[2021,2022,2023,2024,2025,2036,2037,2040]
for i in years:
  print(model_india.predict([[i]]))
# Out:
# [953.81302912]
# [974.52889157]
# [995.24475402]
# [1015.96061646]
# [1036.67647891]
# [1264.55096581]
# [1285.26682826]
# [1347.4144156]

# %% [markdown]
# ***TRAINING THE MODEL FOR PREDICTING USA's CONSUMPTION***

# %%
usa_consumption
# Out:
#              Entity  Year  Per capita electricity (kWh)
# 5301  United States  1985                     11048.449
# 5302  United States  1986                     11023.556
# 5303  United States  1987                     11312.686
# 5304  United States  1988                     11781.619
# 5305  United States  1989                     12635.657
# 5306  United States  1990                     12822.369
# 5307  United States  1991                     12849.582
# 5308  United States  1992                     12780.194
# 5309  United States  1993                     13118.522
# 5310  United States  1994                     13188.340
# 5311  United States  1995                     13453.314
# 5312  United States  1996                     13652.286
# 5313  United States  1997                     13677.552
# 5314  United States  1998                     14012.189
# 5315  United States  1999                     14130.762
# 5316  United States  2000                     13496.477
# ...

# %%
X_usa = usa_consumption.iloc[:,1].values.reshape(36,1)
y_usa = usa_consumption.iloc[:,-1].values

# %%
print(X_usa.shape)
# Out:
# (36, 1)

# %%
print(X_usa)
# Out:
# [[1985]
#  [1986]
#  [1987]
#  [1988]
#  [1989]
#  [1990]
#  [1991]
#  [1992]
#  [1993]
#  [1994]
#  [1995]
#  [1996]
#  [1997]
#  [1998]
#  [1999]
#  [2000]
#  [2001]
#  [2002]
#  [2003]
#  [2004]
#  [2005]
#  [2006]
#  [2007]
#  [2008]
#  [2009]
#  [2010]
#  [2011]
#  [2012]
#  [2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]]

# %%
print(y_usa)
# Out:
# [11048.449 11023.556 11312.686 11781.619 12635.657 12822.369 12849.582
#  12780.194 13118.522 13188.34  13453.314 13652.286 13677.552 14012.189
#  14130.762 13496.477 13129.089 13431.013 13398.815 13581.296 13747.498
#  13650.981 13827.772 13573.567 12896.616 13349.213 13159.021 12889.171
#  12850.686 12881.02  12751.688 12678.9   12483.701 12852.293 12647.457
#  12235.088]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_usa,y_usa, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model_usa = LinearRegression()
model_usa.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_usa.predict(X_test)

# %%
print("Coefficient: ",model_usa.coef_)
print("intercept: ",model_usa.intercept_)
# Out:
# Coefficient:  [27.6314781]
# intercept:  -42332.307973617964

# %% [markdown]
# ***VISUALIZING THE TRAINING SET RESULTS***

# %%
plt.scatter(X_train, y_train, color = 'green',label = "Actual value")
plt.plot(X_train, model_usa.predict(X_train), color = 'blue', label = "Predicted value")
plt.title('UNITED STATES(Training data)',color= "blue")
plt.xlabel('Year',color = "red")
plt.ylabel("per capital electricity consumption(kWh)",color = "red")
plt.legend(loc = 0)
plt.show()

# %% [markdown]
# ***VISUALIZING THE TEST SET RESULTS***

# %%
plt.scatter(X_test, y_test, color = 'green',label = "Actual value")
plt.plot(X_train, model_usa.predict(X_train), color = 'blue', label = "Predicted value")
plt.title('UNITED STATES(Testing data)',color= "blue")
plt.xlabel('Year',color = "red")
plt.ylabel("per capital electricity consumption(kWh)",color = "red")
plt.legend(loc = 0)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test,y_pred,squared  = True)
print(error)
# Out:
# 561670.6658567073

# %%
years=[2021,2022,2023,2024,2025,2036,2037,2040]
for i in years:
  print(model_usa.predict([[i]]))
# Out:
# [13510.90926853]
# [13538.54074663]
# [13566.17222473]
# [13593.80370283]
# [13621.43518093]
# [13925.38144004]
# [13953.01291814]
# [14035.90735245]

# %% [markdown]
# ***TRAINING THE MODEL FOR PREDICTING CHINA's CONSUMPTION***

# %%
china_consumption
# Out:
#      Entity  Year  Per capita electricity (kWh)
# 1022  China  1985                       381.828
# 1023  China  1986                       410.524
# 1024  China  1987                       445.542
# 1025  China  1988                       479.211
# 1026  China  1989                       504.861
# 1027  China  1990                       527.835
# 1028  China  1991                       567.987
# 1029  China  1992                       624.789
# 1030  China  1993                       665.883
# 1031  China  1994                       754.297
# 1032  China  1995                       811.519
# 1033  China  1996                       863.917
# 1034  China  1997                       899.805
# 1035  China  1998                       917.466
# 1036  China  1999                       967.059
# 1037  China  2000                      1022.123
# 1038  China  2001                      1126.855
# 1039  China  2002                      1249.959
# 1040  China  2003                      1413.067
# ...

# %%
X_china = china_consumption.iloc[:,1].values.reshape(36,1)
y_china = china_consumption.iloc[:,-1].values

# %%
print(X_china)
# Out:
# [[1985]
#  [1986]
#  [1987]
#  [1988]
#  [1989]
#  [1990]
#  [1991]
#  [1992]
#  [1993]
#  [1994]
#  [1995]
#  [1996]
#  [1997]
#  [1998]
#  [1999]
#  [2000]
#  [2001]
#  [2002]
#  [2003]
#  [2004]
#  [2005]
#  [2006]
#  [2007]
#  [2008]
#  [2009]
#  [2010]
#  [2011]
#  [2012]
#  [2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]]

# %%
print(y_china)
# Out:
# [ 381.828  410.524  445.542  479.211  504.861  527.835  567.987  624.789
#   665.883  754.297  811.519  863.917  899.805  917.466  967.059 1022.123
#  1126.855 1249.959 1413.067 1633.289 1819.561 2077.55  2397.538 2535.039
#  2699.81  3086.964 3428.557 3602.411 3859.648 4004.776 4080.043 4259.257
#  4538.073 4900.508 5110.046 5296.721]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_china,y_china, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model_china = LinearRegression()
model_china.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_china.predict(X_test)

# %%
print("Coefficient: ",model_china.coef_)
print("intercept: ",model_china.intercept_)
# Out:
# Coefficient:  [138.59991108]
# intercept:  -275483.7864569437

# %% [markdown]
# ***VISUALIZING THE TRAINING SET RESULTS***

# %%
plt.scatter(X_train, y_train, color = 'green',label = "Actual value")
plt.plot(X_train, model_china.predict(X_train), color = 'orange', label = "predicted value")
plt.title('CHINA(Training data)',color= "blue")
plt.xlabel('Year',color = "red")
plt.ylabel("per capital electricity consumption(kWh)",color = "red")
plt.legend(loc = 0)
plt.show()

# %% [markdown]
# ***VISUALIZING THE TEST SET RESULTS***

# %%
plt.scatter(X_test, y_test, color = 'green',label = "Actual value")
plt.plot(X_train, model_china.predict(X_train), color = 'orange',label = "Predicted value")
plt.title('CHINA(Testing data)',color= "blue")
plt.xlabel('Year',color = "red")
plt.ylabel("per capital electricity consumption(kWh)",color = "red")
plt.legend(loc = 0)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test,y_pred, squared = True)
print(error)
# Out:
# 239170.9203440488

# %%
years=[2021,2022,2023,2024,2025,2036,2037,2040]
for i in years:
  print(model_china.predict([[i]]))
print(type(i))
# Out:
# [4626.63383922]
# [4765.23375031]
# [4903.83366139]
# [5042.43357247]
# [5181.03348355]
# [6705.63250545]
# [6844.23241653]
# [7260.03214978]
# <class 'int'>

# %%
from tabulate import tabulate
head = ["Country", "Mean Squared Error"]
mydata = [["India",2793.214567211781],
          ["USA",561670.6658567073],
          ["China",239170.9203440488]]

print(tabulate(mydata, headers = head, tablefmt = "grid"))
# Out:
# +-----------+----------------------+
# | Country   |   Mean Squared Error |
# +===========+======================+
# | India     |              2793.21 |
# +-----------+----------------------+
# | USA       |            561671    |
# +-----------+----------------------+
# | China     |            239171    |
# +-----------+----------------------+
